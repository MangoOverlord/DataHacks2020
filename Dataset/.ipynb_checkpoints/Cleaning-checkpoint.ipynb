# %%
import numpy as np
import pandas as pd

# %%
housingdata = pd.read_csv("SD1970_housing.csv")
populationdata = pd.read_csv("SD1970_population.csv")

# %%
populationdata
# Out:
#        Census Tract Name  Block Group Place Name Total persons  \
# 0     Census Tract 1                1  San Diego           901
# 1     Census Tract 1                2  San Diego           683
# 2     Census Tract 1                3  San Diego           532
# 3     Census Tract 1                4  San Diego           421
# 4     Census Tract 1                5  San Diego           489
# ...                  ...          ...        ...           ...
# 1259  Census Tract 199              3        NaN           271
# 1260  Census Tract 199              3        NaN           259
# 1261  Census Tract 199              9        NaN           444
# 1262  Census Tract 199              9        NaN           550
# 1263  Census Tract 199              9      Vista             6
#
#      Male persons age under 5 years Male persons age 5 years  \
# 0                                31                        6
# 1                                28                        2
# ...

# %%
temp = populationdata.loc[:,'Male persons age under 5 years':'Male persons age 75 and over']

temp = temp.replace("...", np.nan)
temp = temp.dropna()

for col in temp:
    temp[col] = temp[col].astype(str).astype(int)


temp2 = populationdata.loc[:,'Female persons age under 5 years':'Female persons age 75 and over']

temp2 = temp2.replace("...", np.nan)
temp2 = temp2.dropna()

for col in temp2:
    temp2[col] = temp2[col].astype(str).astype(int)

result = pd.DataFrame()
result["total male"] = temp.sum(axis=1)
result["total female"] = temp2.sum(axis=1)
result["total persons"] = populationdata["Total persons"]
result
# Out:
#       total male  total female total persons
# 0            405           496           901
# 1            300           383           683
# 2            249           283           532
# 3            197           224           421
# 4            212           277           489
# ...          ...           ...           ...
# 1259         128           143           271
# 1260         127           132           259
# 1261         233           211           444
# 1262         270           280           550
# 1263           3             3             6
#
# [1174 rows x 3 columns]

# %%
for col in populationdata.loc[:,'Male persons age under 5 years':'Female persons age 75 and over']:
    populationdata[col] = populationdata[col].replace("...", np.nan)

populationdata = populationdata.dropna()

for col in populationdata.loc[:,'Male persons age under 5 years':'Female persons age 75 and over']:
    populationdata[col] = populationdata[col].astype(str).astype(int)


populationdata["Total Male"] = populationdata.loc[:,'Male persons age under 5 years':'Male persons age 75 and over'].sum(axis=1)
populationdata["Total Female"] = populationdata.loc[:,'Female persons age under 5 years':'Female persons age 75 and over'].sum(axis=1)
populationdata
# Out:
# C:\Users\Veronblanc\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Census Tract Name  Block Group  Place Name Total persons  \
# 0     Census Tract 1                1   San Diego           901
# 1     Census Tract 1                2   San Diego           683
# 2     Census Tract 1                3   San Diego           532
# 3     Census Tract 1                4   San Diego           421
# 4     Census Tract 1                5   San Diego           489
# ...                  ...          ...         ...           ...
# 1252  Census Tract 198              9    Carlsbad           568
# 1253  Census Tract 199              1  San Marcos             0
# ...

# %%
roughdraft = pd.read_csv("mergeddata.csv")

# %%
wordFrequency = {}

for y in roughdraft["Place Name_x"]:
	if y in wordFrequency.keys():
		wordFrequency[y] = wordFrequency.get(y)+1
	else: 
		wordFrequency[y] = 1

# %%
print(wordFrequency)
# Out:
# {'San Diego': 652, nan: 112, 'Lemon Grove': 19, 'Spring Valley': 26, 'National City': 62, 'Chula Vista': 81, 'Otay Castle Park': 14, 'Imperial Beach': 20, 'Coronado': 16, 'Grossmont Mount Helix': 16, 'La Mesa': 37, 'El Cajon': 66, 'Santee': 12, 'Lakeside': 8, 'Del Mar': 5, 'Solana Beach': 5, 'Cardiff by the Sea': 5, 'Encinitas': 10, 'Carlsbad': 16, 'Oceanside': 50, 'Vista': 31, 'San Marcos': 1}
