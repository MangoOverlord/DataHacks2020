# %%
import numpy as np
import pandas as pd

# %%
housingdata = pd.read_csv("SD1970_housing.csv")
housingpop = pd.read_csv("SD1970_population.csv")

# %%
boys = housingpop.loc[:, "Male persons age under 5 years":"Male persons age 22-24 years"]
boys
# Out:
#      Male persons age under 5 years Male persons age 5 years  \
# 0                                31                        6
# 1                                28                        2
# 2                                18                        4
# 3                                 9                        3
# 4                                12                        2
# ...                             ...                      ...
# 1259                              5                        1
# 1260                              4                        5
# 1261                             14                        2
# 1262                             12                        1
# 1263                              0                        0
#
#      Male persons age 6 years Male persons age 7-9 years  \
# 0                           9                         29
# 1                           9                         14
# 2                           4                         15
# ...

# %%
M_5_9 = housingpop["Male persons age 5 years"] + housingpop["Male persons age 6 years"] + housingpop["Male persons age 7-9 years"]
M_5_9
#oof this did not work, it concatenated instead
# Out:
# 0       6929
# 1       2914
# 2       4415
# 3        355
# 4        246
#         ...
# 1259     109
# 1260     529
# 1261    2321
# 1262     148
# 1263     000
# Length: 1264, dtype: object

# %%
for col in housingpop.loc[:, 'Male persons age under 5 years':'Female persons age 75 and over']:
    housingpop[col] = housingpop[col].replace('...', np.nan)
housingpop.loc[12, 'Male persons age under 5 years':'Female persons age 75 and over']
# Out:
# Male persons age under 5 years      NaN
# Male persons age 5 years            NaN
# Male persons age 6 years            NaN
# Male persons age 7-9 years          NaN
# Male persons age 10-13 years        NaN
# Male persons age 14 years           NaN
# Male persons age 15 years           NaN
# Male persons age 16 years           NaN
# Male persons age 17 years           NaN
# Male persons age 18 years           NaN
# Male persons age 19 years           NaN
# Male persons age 20 years           NaN
# Male persons age 21 years           NaN
# Male persons age 22-24 years        NaN
# Male persons age 25-34 years        NaN
# Male persons age 35-44 years        NaN
# Male persons age 45-54 years        NaN
# Male persons age 55-59 years        NaN
# Male persons age 60-61 years        NaN
# Male persons age 62-64 years        NaN
# Male persons age 65-74 years        NaN
# Male persons age 75 and over        NaN
# Female persons age under 5 years    NaN
# ...

# %%
housingpop = housingpop.dropna()
housingpop.loc[10:15, 'Male persons age under 5 years':'Female persons age 75 and over']
# Out:
#     Male persons age under 5 years  Male persons age 5 years  \
# 10                              31                         6
# 11                              13                         3
# 13                               0                         0
# 14                              13                         1
# 15                               1                         0
#
#     Male persons age 6 years  Male persons age 7-9 years  \
# 10                         2                          12
# 11                         0                           5
# 13                         0                           0
# 14                         5                           9
# 15                         0                           1
#
#     Male persons age 10-13 years  Male persons age 14 years  \
# 10                            18                          1
# 11                             9                          1
# 13                             1                          0
# ...

# %%
for col in housingpop.loc[:, "Male persons age under 5 years":"Female persons age 75 and over"]:
    housingpop[col] = housingpop[col].astype(str).astype(int)

# %% [markdown]
# want to combine columns into more general age groups: 5-9,

# %%
housingpop['Male persons age 5-9 years'] = housingpop['Male persons age 5 years'] + housingpop['Male persons age 6 years'] + housingpop['Male persons age 7-9 years']
housingpop['Male persons age 5-9 years']
# Out:
# 0       44
# 1       25
# 2       23
# 3       13
# 4       12
#         ..
# 1252    42
# 1253     0
# 1255     2
# 1258     8
# 1263     0
# Name: Male persons age 5-9 years, Length: 1069, dtype: int32
